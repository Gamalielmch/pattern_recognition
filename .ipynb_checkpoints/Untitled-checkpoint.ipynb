# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('Life_Expectancy_Data.csv')
dataset
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# ...

# %%
X = dataset.iloc[0:10, [-1]].values #Feature matrix
y = dataset.iloc[0:10, 3].values #Label Matrix 
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(X, y, 'b.')
ax.set_xlabel('Schooling',fontsize=12)
ax.set_ylabel('Life expectancy',fontsize=12)
# Out:
# Text(0, 0.5, 'Life expectancy')

# %%
# theta = np.array([[0],[0],[0],[0],[0],[0]])
order=10
theta=np.zeros((order,1))
lr =1e-4
n_iter = 50000
y=y.reshape((len(y), 1))

x_b=np.c_[np.ones((len(X),1)),X]
for pot in range(order-2):
    x_b=np.c_[x_b,X**(pot+2)]
    
print(x_b.shape)
j_cost=np.zeros([n_iter])

# ################ Estandarización
nf,nc=x_b.shape
x_bs=x_b
for it in range(1,nc):
    m=np.mean(x_b[:,it])
    std=np.std(x_b[:,it])
    x_bs[:,it]=(x_b[:,it]-m)/std

    
################ Gradiente descendente
for it in range(n_iter):e
    pred = np.dot(x_bs,theta)
    h=(pred - y)
    si=-lr*(x_bs.T.dot(h))
    theta = theta + si
    j_cost[it]=np.sum(np.square(h))
print(theta) 
fig=plt.figure()
plt.plot(j_cost)
# Out:
# (10, 10)
# [[59.38      ]
#  [-0.81757655]
#  [-0.63824141]
#  [-0.42763331]
#  [-0.18624883]
#  [ 0.08510585]
#  [ 0.38535447]
#  [ 0.71319394]
#  [ 1.06713896]
#  [ 1.44556589]]

# %%
X_new=[np.min(x_bs),np.max(x_bs)]
y_predict=np.dot(x_bs,theta)
print(np.sum(np.square(y_predict-y)))
print(np.c_[y_predict,y])
# Out:
# 13.704029601449994
# [[62.19701796 65.        ]
#  [61.56080188 59.9       ]
#  [60.98679921 59.9       ]
#  [60.47109717 59.5       ]
#  [59.23770294 59.2       ]
#  [58.40691822 58.8       ]
#  [57.90274624 58.6       ]
#  [57.71607198 58.1       ]
#  [57.61942866 57.5       ]
#  [57.70141574 57.3       ]]

# %%
xtest=np.linspace(np.min(x_bs),np.max(x_bs),1000)
xtestf=np.c_[np.ones((len(xtest),1)),xtest]
for pot in range(order-2):
    xtestf=np.c_[xtestf,xtest**(pot+2)]
print(xtestf.shape)

# xtest=np.c_[np.ones((len(xtest),1)),xtest,xtest**2,xtest**3,xtest**4,xtest**5]


y_predict=np.dot(xtestf,theta)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(x_bs[:,1], y, c='r', marker='o')
ax.plot(xtestf[:,1],y_predict)
ax.set_xlabel('Schooling',fontsize=12)
ax.set_ylabel('Life expectancy',fontsize=12)
plt.ylim((np.min(y), np.max(y)))
# Out:
# (1000, 10)
# (57.3, 65.0)

# %%
pred = np.dot(x_bs,theta)
print(np.c_[pred,y])
# Out:
# [[61.9734821  65.        ]
#  [61.45560012 59.9       ]
#  [60.977801   59.9       ]
#  [60.53828419 59.5       ]
#  [59.43235997 59.2       ]
#  [58.61203417 58.8       ]
#  [58.03822308 58.6       ]
#  [57.77525492 58.1       ]
#  [57.536748   57.5       ]
#  [57.46021244 57.3       ]]
